# %% [markdown]
# 참고 링크: https://dacon.io/codeshare/1639?dtype=recent

# %%
import pandas as pd

# %%
from selenium import webdriver #동적인 크롤링을 위해 추가
from bs4 import BeautifulSoup  
import time                 
from tqdm.notebook import tqdm

# %%
driver = webdriver.Chrome("../../Downloads/chromedriver")

# %% [markdown]
# ### 9호선 정보 크롤링
# 1~8호선은 공공데이터 정보 있지만, 9호선은 없어서 크롤링 통해서 가져와주었습니다.

# %%
def get_search_page_url(code):
    return 'https://www.metro9.co.kr/site/program/station/info?menuid=001001002&station_code={}'.format(code)

code=901
url = get_search_page_url(code)

# %%
def get_line9_items(line9_items):
    line9_data = []
    for line9_item in line9_items:
        #역명
        try:
            station_name = line9_item.select('div.table_type_h1.mt2 >table > tbody > tr > td:nth-child(1)')[0].text
        except:
            station_name =''
        #주소
        try:
            station_add = line9_item.select('div.table_type_h1.mt2 >table > tbody > tr > td:nth-child(5)')[0].text
        except:
            station_add =''
    
        line9_data.append([station_name,station_add])
    return line9_data

# %%
driver = webdriver.Chrome("../../Downloads/chromedriver")

line9_data_total=[]

#진행상황 출력
for code in tqdm(range(901,939)):
    url = get_search_page_url(code)
    driver.get(url)
    time.sleep(3) # 페이지 로딩하는데 시간이 걸림
    
    #현재 페이지 html문서 가져오가
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    
    line9_items =  soup.select('div.inner')
    line9_data_list = get_line9_items(line9_items)
    
    line9_data_total = line9_data_total + line9_data_list
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=38.0), HTML(value='')))

# %%
# dataframe 으로 만들어주기
data = pd.DataFrame(line9_data_total)
data.columns = ['역명','상세주소']
data['호선'] = '9'
data
# Out:
#         역명                           상세주소 호선
# 0       개화            서울특별시 강서구 개화동로8길 19  9
# 1     김포공항             서울특별시 강서구 하늘길 지하77  9
# 2     공항시장           서울특별시 강서구 방화동로 지하30   9
# 3      신방화           서울특별시 강서구 방화대로 지하301  9
# 4     마곡나루           서울특별시 강서구 마곡중앙5로 지하2  9
# 5     양천향교            서울특별시 강서구 양천로 지하341  9
# 6       가양            서울특별시 강서구 양천로 지하485  9
# 7       증미            서울특별시 강서구 양천로 지하560  9
# 8       등촌           서울특별시 강서구 공항대로 지하529  9
# 9       염창           서울특별시 강서구 공항대로 지하631  9
# 10     신목동          서울특별시 양천구 목동중앙로 지하217  9
# 11     선유도           서울특별시 영등포구 양평로 지하124  9
# 12      당산             서울특별시 영등포구 당산로 229  9
# 13   국회의사당          서울특별시 영등포구 국회대로 지하758  9
# 14     여의도  서울특별시 영등포구 의사당대로 지하101 (여의도동)  9
# 15      샛강         서울특별시 영등포구 의사당대로 지하166  9
# 16     노량진           서울특별시 동작구 노량진로 지하130  9
# 17      노들      서울특별시 동작구 노량진로 지하238 (본동)  9
# 18      흑석       서울특별시 동작구 현충로 지하90 (흑석동)  9
# 19      동작      서울특별시 동작구 현충로 지하220 (동작동)  9
# 20     구반포            서울특별시 서초구 신반포로 지하17  9
# 21     신반포           서울특별시 서초구 신반포로 지하105  9
# 22   고속터미널           서울특별시 서초구 신반포로 지하188  9
# 23      사평           서울특별시 서초구 사평대로 지하285  9
# 24     신논현           서울특별시 강남구 봉은사로 지하102  9
# 25      언주             서울특별시 강남구 봉은사로 201  9
# 26     선정릉              서울특별시 강남구 선릉로 580  9
# 27    삼성중앙             서울특별시 강남구 봉은사로 501  9
# 28     봉은사             서울특별시 강남구 봉은사로 601  9
# 29   종합운동장              서울특별시 송파구 올림픽로 23  9
# 30      삼전            서울특별시 송파구 백제고분로 187  9
# 31    석촌고분              서울특별시 송파구 삼학사로 53  9
# 32      석촌             서울특별시 송파구 송파대로 439  9
# 33    송파나루            서울특별시 송파구 백제고분로 446  9
# 34    한성백제                   송파구 위례성대로 51  9
# 35   올림픽공원            서울특별시 송파구 양재대로 1233  9
# 36    둔촌오륜             서울특별시 강동구 강동대로 305  9
# 37  중앙보훈병원              서울특별시 강동구 명일로 117  9

# %% [markdown]
# ### 1~8호선 정보 공공데이터

# %%
df=pd.read_excel('data/subwayadd.xlsx')
df
# Out:
#     Unnamed: 0        Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           연번                역명         호선          구          동
# 1            1                서울          1         중구        봉래동
# 2            2                시청          1         중구         정동
# 3            3                종각          1        종로구       종로1가
# 4            4              종로3가          1        종로구       종로3가
# ..         ...               ...        ...        ...        ...
# 274        274  남한산성입구(성남법원•검찰청)          8        성남시    수정구 단대동
# 275        275             단대오거리          8        성남시    수정구 신흥동
# 276        276                신흥          8        성남시    수정구 신흥동
# 277        277                수진          8        성남시    수정구 수진동
# 278        278                모란          8        성남시    수정구 수진동
#
#                           Unnamed: 5 Unnamed: 6
# 0                               상세주소       전화번호
# 1        서울특별시 중구 봉래동2가 122 서울역(1호선)  6110-1331
# 2           서울특별시 중구 정동 5-5 시청역(1호선)  6110-1321
# 3          서울특별시 종로구 종로1가 54 종각지하철역사  6110-1311
# 4    서울특별시 종로3가 10-5  1호선 종로3가역(1호선)  6110-1301
# ..                               ...        ...
# 274       경기도 성남시 수정구 단대동 96 남한산성입구역  6311-8220
# 275      경기도 성남시 수정구 신흥동 2467 단대오거리역  6311-8230
# 276         경기도 성남시 수정구 신흥동 2467 신흥역  6311-8240
# 277       경기도 성남시 수정구 수진동 2205-1 수진역  6311-8250
# 278         경기도 성남시 수정구 수진동 4808 모란역  6311-8260
#
# [279 rows x 7 columns]

# %% [markdown]
# ### Data Cleansing
#
# 1) index와 연번이 동일한 데이터여서 중복 제거해줍니다.
#
# 2) columns명이 0번째 row에 입력되어 있어서 columns으로 지정해줍니다.

# %%
df.columns=list(df.iloc[0, :])

# %%
df=df.drop(index=0)

# %%
df.index = df['연번']
df=df.drop(columns='연번',axis=0)
df
# Out:
#                    역명 호선    구        동                             상세주소  \
# 연번
# 1                  서울  1   중구      봉래동      서울특별시 중구 봉래동2가 122 서울역(1호선)
# 2                  시청  1   중구       정동         서울특별시 중구 정동 5-5 시청역(1호선)
# 3                  종각  1  종로구     종로1가        서울특별시 종로구 종로1가 54 종각지하철역사
# 4                종로3가  1  종로구     종로3가  서울특별시 종로3가 10-5  1호선 종로3가역(1호선)
# 5                종로5가  1  종로구     종로5가    서울특별시 종로구 종로5가 82-1 1호선 종로5가역
# ..                ... ..  ...      ...                              ...
# 274  남한산성입구(성남법원•검찰청)  8  성남시  수정구 단대동       경기도 성남시 수정구 단대동 96 남한산성입구역
# 275             단대오거리  8  성남시  수정구 신흥동      경기도 성남시 수정구 신흥동 2467 단대오거리역
# 276                신흥  8  성남시  수정구 신흥동         경기도 성남시 수정구 신흥동 2467 신흥역
# 277                수진  8  성남시  수정구 수진동       경기도 성남시 수정구 수진동 2205-1 수진역
# 278                모란  8  성남시  수정구 수진동         경기도 성남시 수정구 수진동 4808 모란역
#
#           전화번호
# 연번
# 1    6110-1331
# 2    6110-1321
# 3    6110-1311
# 4    6110-1301
# 5    6110-1291
# ..         ...
# 274  6311-8220
# 275  6311-8230
# 276  6311-8240
# 277  6311-8250
# 278  6311-8260
#
# [278 rows x 6 columns]

# %% [markdown]
# 3) 사당 4호선, 사당 1호선 이렇게 같은 역에 여러개의 호선이 있을 경우 중복해서 위치 정보가 있습니다.
# 전화번호가 아닌, 위치정보만 필요하기 때문에 중복을 제거해줍니다.

# %%
df=df.drop_duplicates('역명')

# %%
df=df[['역명','상세주소']]

# %%
data=data[['역명','상세주소']]

# %%
final=pd.concat([df,data])
final
# Out:
#         역명                             상세주소
# 1       서울      서울특별시 중구 봉래동2가 122 서울역(1호선)
# 2       시청         서울특별시 중구 정동 5-5 시청역(1호선)
# 3       종각        서울특별시 종로구 종로1가 54 종각지하철역사
# 4     종로3가  서울특별시 종로3가 10-5  1호선 종로3가역(1호선)
# 5     종로5가    서울특별시 종로구 종로5가 82-1 1호선 종로5가역
# ..     ...                              ...
# 33    송파나루              서울특별시 송파구 백제고분로 446
# 34    한성백제                     송파구 위례성대로 51
# 35   올림픽공원              서울특별시 송파구 양재대로 1233
# 36    둔촌오륜               서울특별시 강동구 강동대로 305
# 37  중앙보훈병원                서울특별시 강동구 명일로 117
#
# [282 rows x 2 columns]

# %% [markdown]
# ### 주소지 정보에 위도, 경도 추가해서 읽어오기
#
# - 구글스프레드 시트에서 부가기능으로 사용가능한 확장프로그램 활용 <a href="https://gsuite.google.com/marketplace/app/geocode_by_awesome_table/904124517349"> 링크 </a>

# %%
ad=pd.read_csv('data/add_all2.csv')

# %% [markdown]
# ### 시각화 연습
#
# 역 위치를 지도맵과 scatterplot으로 각각 그려보았습니다.

# %%
import folium
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font',family='AppleGothic')
plt.rc('axes', unicode_minus=False)

import os
if os.name == 'posix':
    plt.rc("font", family="AppleGothic")
else:
    plt.rc("font", family="Malgun Gothic")

# %%
#folium 라이브러리 활용해서 지도맵 위에 그리기
center = [37.541,126.986]
m=folium.Map(location=center, zoom_start=12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(
    location=[37.5657037,126.9768616],
    popup='시청',
    icon=folium.Icon(icon='cloud')
).add_to(m)
folium.Marker(
    location=[37.4970172,127.0281681],
    popup='강남역',
    icon=folium.Icon(color='green')
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ad
# Out:
#          역명                             상세주소   Latitude   Longitude
# 0        서울      서울특별시 중구 봉래동2가 122 서울역(1호선)  37.557407  126.969500
# 1        시청         서울특별시 중구 정동 5-5 시청역(1호선)  37.565704  126.976862
# 2        종각        서울특별시 종로구 종로1가 54 종각지하철역사  37.570178  126.983116
# 3      종로3가  서울특별시 종로3가 10-5  1호선 종로3가역(1호선)  37.570432  126.992190
# 4      종로5가    서울특별시 종로구 종로5가 82-1 1호선 종로5가역  37.570831  127.002351
# ..      ...                              ...        ...         ...
# 277    송파나루              서울특별시 송파구 백제고분로 446  37.510428  127.112746
# 278    한성백제                     송파구 위례성대로 51  37.513208  127.122946
# 279   올림픽공원              서울특별시 송파구 양재대로 1233  37.516449  127.131107
# 280    둔촌오륜               서울특별시 강동구 강동대로 305  37.520010  127.140673
# 281  중앙보훈병원                서울특별시 강동구 명일로 117  37.529317  127.142437
#
# [282 rows x 4 columns]

# %% [markdown]
# ### 임의로 각 역에 유동인구 데이터를 설정

# %%
ad['유동인구'] = 10
ad.loc[ad['역명'] =='서울','유동인구'] = 500
ad.loc[ad['역명'] =='강남','유동인구'] = 1000
ad.loc[ad['역명'] =='여의도','유동인구'] = 800

# %%
# 전체 역 위치 sactterplot으로 시각화
plt.figure(figsize=(8,6))
sns.scatterplot(data=ad,y='Latitude',x='Longitude',color='gray',size='유동인구')
# 서울역 -> 레드
sns.scatterplot(data=ad[ad['역명'] == '서울'],y='Latitude',x='Longitude',color='r',size='유동인구')
# 강남역 -> 노랑
sns.scatterplot(data=ad[ad['역명'] == '강남'],y='Latitude',x='Longitude',color='y',size='유동인구')
# 여의도 -> 블루
sns.scatterplot(data=ad[ad['역명'] == '여의도'],y='Latitude',x='Longitude',color='b',size='유동인구')

# %%
# 전체 역 위치 sactterplot으로 시각화
plt.figure(figsize=(8,6))
sns.scatterplot(data=ad,y='Latitude',x='Longitude',hue='유동인구',size='유동인구')

# %%
ad['유동인구']=ad['유동인구'].astype('float64')

# %%
map=folium.Map(location=[37.544,127],zoom_start=13)
for n in ad.index:
    name = ad.loc[n,'역명']
    location = [ad.loc[n,'Latitude'],ad.loc[n,'Longitude']]
    radius = ad.loc[n,'유동인구'] /50
    popup = ad.loc[n,'역명']
    folium.CircleMarker(
        location = location,
        popup = popup,
        radius = radius,
        fill = True
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map2 = folium.Map(location=[37.544,127], tiles='stamentoner', zoom_start=13)
for n in ad.index:
    name = ad.loc[n,'역명']
    location = [ad.loc[n,'Latitude'],ad.loc[n,'Longitude']]
    address = ad.loc[n,'상세주소']
    popup = f'{name}'
    folium.Marker(
        location = location,
        popup = popup,
        
    ).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### tiles
# stamentoner
#
# openstreetmap
#
# mapquestiopenaerial
#
# stamenwatercolor
#
# stamenterrain
#
# mapboxbright
#
# cartodbdark_matter

# %%
map3 = folium.Map(location=[37.544,127], tiles='openstreetmap', zoom_start=13)
for n in ad.index:
    name = ad.loc[n,'역명']
    location = [ad.loc[n,'Latitude'],ad.loc[n,'Longitude']]
    address = ad.loc[n,'상세주소']
    popup = f'{name}'
    folium.Marker(
        location = location,
        popup = popup,
        
    ).add_to(map3)
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map4 = folium.Map(location=[37.544,127], tiles='stamenwatercolor', zoom_start=13)
for n in ad.index:
    name = ad.loc[n,'역명']
    location = [ad.loc[n,'Latitude'],ad.loc[n,'Longitude']]
    address = ad.loc[n,'상세주소']
    popup = f'{name}'
    folium.Marker(
        location = location,
        popup = popup,
        
    ).add_to(map4)
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### choropleth maps

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
